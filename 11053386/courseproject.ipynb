# %% [markdown]
# ### SAMUEL AMPOMAH

# %% [markdown]
# ### 11053386

# %% [markdown]
# ### CPEN

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB 653.6 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/10.5 MB 1.4 MB/s eta 0:00:08
#     --------------------------------------- 0.2/10.5 MB 1.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/10.5 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/10.5 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/10.5 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/10.5 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/10.5 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/10.5 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.5 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/10.5 MB 1.9 MB/s eta 0:00:05
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.4 kB ? eta -:--:--
#      ---------------------- ---------------- 92.2/160.4 kB 1.3 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/160.4 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 160.4/160.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.6 MB 3.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/7.6 MB 2.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/7.6 MB 3.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/7.6 MB 3.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.6 MB 3.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.6 MB 4.0 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
red_wine=pd.read_csv('red_wine.csv')

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wine.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
red_wine[red_wine.isnull().any(axis=1)]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6              7.9             0.600         0.06             1.6        NaN
# 14             8.9             0.620         0.18             3.8      0.176
# 20             8.9             0.220         0.48             1.8      0.077
# 29             7.8               NaN         0.00             2.0      0.082
# 616            9.6             0.600         0.50             2.3      0.079
# 617           11.5             0.310         0.51             2.2        NaN
# 620            8.3             0.540         0.24             3.4        NaN
# 629            7.6             0.685         0.23             2.3        NaN
# 631            NaN             0.280         0.54             2.7      0.105
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6                   15.0                  59.0   0.9964  3.30       0.46
# ...

# %%
def fill_null(col):
   red_wine[col] = red_wine[col].fillna(red_wine[col].mean())
   return red_wine[col]

# %%
fill_null('volatile acidity')
# Out:
# 0       0.700
# 1       0.880
# 2       0.760
# 3       0.280
# 4       0.700
#         ...
# 1594    0.600
# 1595    0.550
# 1596    0.510
# 1597    0.645
# 1598    0.310
# Name: volatile acidity, Length: 1599, dtype: float64

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
fill_null('fixed acidity')
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
fill_null('chlorides')
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1599, dtype: float64

# %%
fill_null('free sulfur dioxide')
# Out:
# 0       11.0
# 1       25.0
# 2       15.0
# 3       17.0
# 4       11.0
#         ...
# 1594    32.0
# 1595    39.0
# 1596    29.0
# 1597    32.0
# 1598    18.0
# Name: free sulfur dioxide, Length: 1599, dtype: float64

# %%
fill_null('density')
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
#          ...
# 1594    0.99490
# 1595    0.99512
# 1596    0.99574
# 1597    0.99547
# 1598    0.99549
# Name: density, Length: 1599, dtype: float64

# %%
fill_null('quality')
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1594    5.0
# 1595    6.0
# 1596    6.0
# 1597    5.0
# 1598    6.0
# Name: quality, Length: 1599, dtype: float64

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
red_wine.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.bar(red_wine['quality'], red_wine['alcohol'])
plt.title('A Graph Of Alcohol Against Quality')
plt.xlabel("quality")
plt.ylabel("alcohol")
# Out:
# Text(0, 0.5, 'alcohol')

# %% [markdown]
# ###### From the graph above,at most times  as the aclcohol increases the quality also increases or remain steady
